# %% [markdown]
# <a href="https://colab.research.google.com/github/DorMm1/Ono-Image-Processing/blob/master/Part_B_of_Final_Project_of_Image_Processing_DataSet_Creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Final Project Image Processing, Ono College - B.Sc Computer Science**
# ## Google Colab Notebook 2/3
#
# ### Students:
# - StudentName = 'Dor Menahem', StudentID = '318687746', StudentMobile = '052-8028427'
# - StudentName = 'Nir Barash', StudentID = '207541434', StudentMobile = '054-3172167'

# %%
import cv2
import numpy as np
import random
from google.colab import drive

# Mount Google Drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Helper function to get intensity range for each shape type
def get_intensity_range(shape_type):
    if shape_type == "circle":
        return 26, 50
    elif shape_type == "rectangle":
        return 51, 75
    elif shape_type == "triangle":
        return 76, 100
    elif shape_type == "trapezoid":
        return 101, 125
    elif shape_type == "ellipse":
        return 126, 150
    elif shape_type == "square":
        return 151, 175
    elif shape_type == "half_circle":
        return 176, 200
    elif shape_type == "pentagon":
        return 201, 225
    elif shape_type == "hexagon":
        return 226, 250

# Function to generate a random shape and associated metadata
def generate_shape(image):
    h, w = image.shape[:2]

    # Generate random shape
    shape_type = random.choice(["circle", "rectangle", "triangle", "trapezoid", "ellipse", "square", "half_circle", "pentagon", "hexagon"])
    intensity_range_min, intensity_range_max = get_intensity_range(shape_type)
    intensity_range = random.randint(intensity_range_min, intensity_range_max)
    color = random.randint(intensity_range - 25, min(intensity_range, 255))
    size = random.randint(10, min(h, w) // 4)
    x, y = random.randint(size, w - size), random.randint(size, h - size)

    # Draw shape on the image
    if shape_type == "circle":
        cv2.circle(image, (x, y), size, color, -1)
    elif shape_type == "rectangle":
        cv2.rectangle(image, (x - size, y - size), (x + size, y + size), color, -1)
    elif shape_type == "triangle":
        points = np.array([[x, y - size], [x - size, y + size], [x + size, y + size]])
        cv2.drawContours(image, [points], 0, color, -1)
    elif shape_type == "trapezoid":
        points = np.array([[x - size, y + size], [x + size, y + size], [x - size // 2, y - size], [x + size // 2, y - size]])
        cv2.drawContours(image, [points], 0, color, -1)
    elif shape_type == "ellipse":
        cv2.ellipse(image, (x, y), (size, size // 2), 0, 0, 360, color, -1)
    elif shape_type == "square":
        cv2.rectangle(image, (x - size, y - size), (x + size, y + size), color, -1)
    elif shape_type == "half_circle":
        cv2.ellipse(image, (x, y), (size, size // 2), 0, -180, 0, color, -1)
    elif shape_type == "pentagon":
        side_length = size
        angle = 360 / 5
        pentagon_points = []
        for i in range(5):
            pentagon_points.append((int(x + side_length * np.cos(np.radians(i * angle))), int(y + side_length * np.sin(np.radians(i * angle)))))
        cv2.fillPoly(image, [np.array(pentagon_points)], color)
    elif shape_type == "hexagon":
        side_length = size
        angle = 360 / 6
        hexagon_points = []
        for i in range(6):
            hexagon_points.append((int(x + side_length * np.cos(np.radians(i * angle))), int(y + side_length * np.sin(np.radians(i * angle)))))
        cv2.fillPoly(image, [np.array(hexagon_points)], color)

    # Generate metadata for the shape
    metadata = {"shape_type": shape_type, "color": color, "size": size, "position": (x, y)}

    # Return metadata
    return metadata

# Function to generate a random line and associated metadata
def generate_line(image):
    h, w = image.shape[:2]

    # Generate random line
    x1, y1 = random.randint(0, w), random.randint(0, h)
    x2, y2 = random.randint(0, w), random.randint(0, h)

    # Ensure x1 and x2 are not equal to avoid division by zero
    while x1 == x2:
        x2 = random.randint(0, w)

    # Calculate coefficients of the line equation (y = mx + c)
    m = (y2 - y1) / (x2 - x1)
    c = y1 - m * x1

    # Generate random color for the line
    color = random.randint(0, 25)

    # Generate metadata for the line
    metadata = {"shape_type": "line", "color": color, "a": m, "b": c}

    # Draw line on the image
    cv2.line(image, (x1, y1), (x2, y2), color, 1)

    # Return metadata
    return metadata

import json
# Decided using json to help the classification process in the next notebook.
# Parsing JSON into MetaData Object is easier than plain text

# Function to generate an image with shapes and a line
def generate_image():
    image = np.zeros((128, 128), dtype=np.uint8)
    shape_metadata = []

    # Randomize number of shapes between 0 and 9
    num_shapes = random.randint(0, 9)

    # Generate shapes and collect metadata
    for _ in range(num_shapes):
        shape_metadata.append(generate_shape(image))

    # Generate line and collect metadata
    line_metadata = generate_line(image)

    # Create dictionary to hold image and metadata
    data = {
        "shape_metadata": shape_metadata,
        "line_metadata": line_metadata
    }

    # Convert dictionary to JSON string
    json_data = json.dumps(data)

    return image, json_data

# %% [markdown]
# num_train = 5600
# num_test = 1400
#
# Because when we attempted to create the dataset with 70,000 instead of 7,000 the google drive was failing. The logic is the same just diveded the amount by 10.

# %%
import tempfile
import shutil
import os

# Generate and save images locally
temp_dir = tempfile.mkdtemp()
num_train = 5600
num_test = 1400

for subset_folder in ["train", "test"]:
    os.makedirs(os.path.join(temp_dir, subset_folder), exist_ok=True)
    iterations = 0
    if(subset_folder == "train"):
      iterations = num_train
    else:
      iterations = num_test
    for i in range(iterations):
        image, json_metadata = generate_image()
        filename = f"{i}.jpg"
        print("Starting generation for: " + temp_dir +"/"+ subset_folder+"/"+filename)
        cv2.imwrite(f"{temp_dir}/{subset_folder}/{filename}", image)
        # Save metadata
        with open(f"{temp_dir}/{subset_folder}/{filename}.txt", "w") as f:
            f.write(json_metadata)

print("Image generation completed.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Starting generation for: /tmp/tmp1h_da9sy/train/2001.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2002.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2003.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2004.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2005.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2006.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2007.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2008.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2009.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2010.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2011.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2012.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2013.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2014.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2015.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2016.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2017.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2018.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2019.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2020.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2021.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2022.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2023.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2024.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2025.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2026.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2027.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2028.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2029.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2030.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2031.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2032.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2033.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2034.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2035.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2036.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2037.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2038.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2039.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2040.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2041.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2042.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2043.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2044.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2045.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2046.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2047.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2048.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2049.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2050.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2051.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2052.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2053.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2054.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2055.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2056.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2057.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2058.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2059.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2060.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2061.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2062.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2063.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2064.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2065.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2066.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2067.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2068.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2069.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2070.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2071.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2072.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2073.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2074.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2075.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2076.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2077.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2078.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2079.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2080.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2081.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2082.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2083.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2084.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2085.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2086.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2087.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2088.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2089.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2090.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2091.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2092.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2093.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2094.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2095.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2096.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2097.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2098.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2099.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2100.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2101.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2102.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2103.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2104.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2105.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2106.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2107.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2108.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2109.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2110.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2111.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2112.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2113.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2114.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2115.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2116.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2117.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2118.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2119.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2120.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2121.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2122.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2123.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2124.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2125.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2126.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2127.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2128.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2129.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2130.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2131.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2132.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2133.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2134.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2135.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2136.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2137.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2138.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2139.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2140.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2141.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2142.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2143.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2144.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2145.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2146.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2147.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2148.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2149.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/2150.jpg
# Starting generation for: /tmp/tmp1h_da9sy/train/
jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1206.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1207.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1208.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1209.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1210.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1211.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1212.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1213.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1214.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1215.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1216.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1217.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1218.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1219.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1220.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1221.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1222.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1223.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1224.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1225.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1226.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1227.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1228.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1229.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1230.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1231.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1232.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1233.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1234.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1235.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1236.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1237.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1238.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1239.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1240.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1241.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1242.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1243.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1244.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1245.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1246.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1247.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1248.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1249.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1250.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1251.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1252.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1253.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1254.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1255.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1256.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1257.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1258.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1259.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1260.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1261.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1262.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1263.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1264.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1265.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1266.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1267.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1268.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1269.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1270.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1271.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1272.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1273.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1274.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1275.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1276.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1277.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1278.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1279.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1280.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1281.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1282.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1283.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1284.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1285.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1286.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1287.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1288.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1289.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1290.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1291.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1292.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1293.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1294.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1295.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1296.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1297.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1298.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1299.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1300.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1301.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1302.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1303.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1304.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1305.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1306.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1307.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1308.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1309.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1310.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1311.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1312.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1313.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1314.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1315.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1316.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1317.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1318.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1319.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1320.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1321.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1322.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1323.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1324.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1325.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1326.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1327.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1328.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1329.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1330.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1331.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1332.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1333.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1334.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1335.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1336.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1337.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1338.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1339.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1340.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1341.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1342.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1343.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1344.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1345.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1346.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1347.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1348.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1349.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1350.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1351.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1352.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1353.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1354.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1355.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1356.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1357.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1358.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1359.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1360.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1361.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1362.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1363.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1364.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1365.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1366.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1367.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1368.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1369.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1370.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1371.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1372.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1373.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1374.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1375.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1376.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1377.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1378.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1379.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1380.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1381.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1382.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1383.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1384.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1385.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1386.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1387.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1388.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1389.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1390.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1391.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1392.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1393.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1394.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1395.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1396.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1397.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1398.jpg
# Starting generation for: /tmp/tmp1h_da9sy/test/1399.jpg
# Image generation completed.

# %%
# Copy images to Google Drive
dataset_folder = "/content/drive/My Drive/Part_B_DataSet"  # Destination folder in Google Drive
for subset_folder in ["train", "test"]:
    print("Started Copying: " + subset_folder)
    shutil.copytree(f"{temp_dir}/{subset_folder}", f"{dataset_folder}/{subset_folder}")
    print("Finished Copying: " + subset_folder)

print("Images copied to Google Drive.")
# Out:
# Started Copying: train
# Finished Copying: train
# Started Copying: test
# Finished Copying: test
# Images copied to Google Drive.

# %% [markdown]
# Also copy the generated images into a zip just to double check the generated images and metadata is good

# %%
import shutil
import os
import zipfile
from google.colab import files

def copy_folder_to_local(src_folder, dest_zip_file):
    """
    Copies a folder from Google Colab to the local machine by compressing it into a ZIP archive.

    Args:
    - src_folder (str): Path to the source folder in Google Colab.
    - dest_zip_file (str): Path to the destination ZIP file on the local machine.
    """
    # Ensure that the source folder exists
    if not os.path.exists(src_folder):
        print(f"Source folder '{src_folder}' does not exist.")
        return

    # Create a ZIP archive of the source folder
    with zipfile.ZipFile(dest_zip_file, 'w', zipfile.ZIP_DEFLATED) as zipf:
        # Walk through the source folder and add each file to the ZIP archive
        for root, dirs, files in os.walk(src_folder):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, src_folder))

    print(f"Folder '{src_folder}' compressed to '{dest_zip_file}'.")


src_folder = temp_dir
dest_zip_file = '/content/images.zip'
copy_folder_to_local(src_folder, dest_zip_file)
files.download(dest_zip_file)
# Out:
# Folder '/tmp/tmp1h_da9sy' compressed to '/content/images.zip'.
